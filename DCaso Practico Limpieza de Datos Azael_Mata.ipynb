# %% [markdown]
# CASO PRACTICO AZAEL

# %% [markdown]
# #Analisis de Tuberculosis

# %% [markdown]
# **Planteamiento**
#
# Usted trabaja para la Organización Mundial de la Salud como analista de información. El consejo directivo se reunirá para revisar los datos más recientes de casos de tuberculosis.
#
# Los datos han llegado con la información más reciente y necesita prepararlos para mostrar la información a los líderes de la organización.
#
# El objetivo de la junta es entender la situación actual de tuberculosis, y las tendencias por región e identificar países que han sido casos de éxito y aquellos que necesiten mayor apoyo con la gestión de la enfermedad.
#
# Tenga en mente las metas de la ONU para terminar con la Tuberculosis para 2025:
# *  Reducción en la tasa de incidencia del 50% 2015 vs 2025.
# *  Reducción en 75% el número de muertes 2015 vs 2025

# %% [markdown]
# [Documentacion de los datos de tuberculosis] (https://tidyr.tidyverse.org/reference/who.html)

# %% [markdown]
# **¿Que es la tuberculosis?**
# R: *La tuberculosis (TB) es una enfermedad infecciosa causada por la bacteria Mycobacterium tuberculosis, que generalmente afecta los pulmones, pero puede afectar otras partes del cuerpo como los riñones, la columna vertebral o el cerebro. La TB se transmite de persona a persona a través del aire, cuando alguien con TB activa tose, estornuda o habla, liberando gotas que contienen las bacterias.*
#
# **¿Cual son los sintomas**
# R: *Las personas con infección tuberculosa no presentan síntomas ni pueden transmitir el bacilo, y solo una proporción enferma y presenta síntomas. Los bebés y los niños corren más riesgo de enfermar.*
#
# *Los bacilos tuberculosos se pueden multiplicar en el organismo y afectar a varios órganos, momento en el que se considera que la persona tiene tuberculosis. Los síntomas pueden ser leves durante muchos meses, lo cual facilita la transmisión inadvertida a otras personas. Además, algunas personas con tuberculosis no presentan síntomas.*
#
# *Los síntomas habituales de la tuberculosis son:*
# * *Tos prolongada (a veces con sangre)*
# * *Dolor en el pecho*
# * *Cansancio*
# * *pérdida de peso*
# * *Fiebre*
# * *Sudores nocturnos*
#
# *Los síntomas dependen de la parte del cuerpo afectada. Aunque la tuberculosis suele afectar a los pulmones, también pueden verse afectados los riñones, el cerebro, la columna vertebral y la piel.*
#
# **¿Dónde se encuentra distribuida la Tuberculosis en Mexico?**
# R:*Más de la mitad de todos los municipios del país, notifican casos de tuberculosis cada año, prácticamente hay TB en todo el territorio mexicano, sin embargo las entidades federativas de mayor número de nuevos casos y muertes por esta causa son: Baja California, Veracruz, Guerrero, Sonora, Tamaulipas, Chiapas, Nuevo León y Tabasco. La mayor concentración de afectados se encuentran en las grandes ciudades o municipios de mayor número de población (Tijuana, Mexico)*
#
# **¿Dónde se encuentra distribuida la Tuberculosis a nivel Mundial?**
# R:*En 2023, el mayor número de nuevos casos se registró en la Región de Asia Sudoriental de la OMS (el 45%), seguida de la de África (el 24%) y la del Pacífico Occidental (el 17%). Alrededor del 87% de los nuevos casos se produjeron en los 30 países con alta carga de tuberculosis, y más de dos tercios del total mundial se concentraron en Bangladesh, China, Filipinas, India, Indonesia, Nigeria, Pakistán y la República Democrática del Congo.*
#
# **¿Por qué la Tuberculosis es un problema de salud ?**
# R:*En la Estrategia Fin a la Tuberculosis de la OMS se ha fijado el objetivo de que ninguna persona con tuberculosis (y sus hogares) tengan que hacer frente a gastos catastróficos para tratar esta enfermedad (es decir, que tengan que hacer un gasto superior al 20% de la renta doméstica). Sin embargo, de las personas con esta enfermedad que están en tratamiento y de sus hogares, alrededor del 50% enfrentan gastos catastróficos por ese motivo.*
#
# **¿Qué grupos etarios son los mas afectados?**
# R:*Se calcula que en 2023 contrajeron tuberculosis 10,8 millones de personas en todo el mundo: 6,0 millones de hombres, 3,6 millones de mujeres y 1,3 millones de niños. Aunque es una enfermedad presente en todos los países y grupos de edad, se puede prevenir y curar.*

# %%
from google.colab import drive
import pandas as pd
import numpy as np
drive.mount ('/content/drive')

pd.set_option ('display.max_rows', None)
pd.set_option ('display.max_columns', None)
# Out:
# Mounted at /content/drive

# %%
pop = pd.read_csv('/content/drive/MyDrive/Datos/PyAza/population.csv')

who = pd.read_csv('/content/drive/MyDrive/Datos/PyAza/who.csv')

# %%
pop.head()
# Out:
#        country  year  population
# 0  Afghanistan  1995    17586073
# 1  Afghanistan  1996    18415307
# 2  Afghanistan  1997    19021226
# 3  Afghanistan  1998    19496836
# 4  Afghanistan  1999    19987071

# %%
who.head(20)
# Out:
#         country iso2 iso3  year  new_sp_m014  new_sp_m1524  new_sp_m2534  \
# 0   Afghanistan   AF  AFG  1980          NaN           NaN           NaN
# 1   Afghanistan   AF  AFG  1981          NaN           NaN           NaN
# 2   Afghanistan   AF  AFG  1982          NaN           NaN           NaN
# 3   Afghanistan   AF  AFG  1983          NaN           NaN           NaN
# 4   Afghanistan   AF  AFG  1984          NaN           NaN           NaN
# 5   Afghanistan   AF  AFG  1985          NaN           NaN           NaN
# 6   Afghanistan   AF  AFG  1986          NaN           NaN           NaN
# 7   Afghanistan   AF  AFG  1987          NaN           NaN           NaN
# 8   Afghanistan   AF  AFG  1988          NaN           NaN           NaN
# 9   Afghanistan   AF  AFG  1989          NaN           NaN           NaN
# 10  Afghanistan   AF  AFG  1990          NaN           NaN           NaN
# 11  Afghanistan   AF  AFG  1991          NaN           NaN           NaN
# ...

# %% [markdown]
# #Limpieza y manipulacion de Datos
# Explorar los valores nulos

# %%
who.isna().sum() #funcion para saber cuantos valores nulos hay
# Out:
# country            0
# iso2              34
# iso3               0
# year               0
# new_sp_m014     4067
# new_sp_m1524    4031
# new_sp_m2534    4034
# new_sp_m3544    4021
# new_sp_m4554    4017
# new_sp_m5564    4022
# new_sp_m65      4031
# new_sp_f014     4066
# new_sp_f1524    4046
# new_sp_f2534    4040
# new_sp_f3544    4041
# new_sp_f4554    4036
# new_sp_f5564    4045
# new_sp_f65      4043
# new_sn_m014     6195
# new_sn_m1524    6210
# new_sn_m2534    6218
# new_sn_m3544    6215
# new_sn_m4554    6213
# new_sn_m5564    6219
# new_sn_m65      6220
# new_sn_f014     6200
# new_sn_f1524    6218
# new_sn_f2534    6224
# new_sn_f3544    6220
# new_sn_f4554    6222
# new_sn_f5564    6223
# new_sn_f65      6221
# new_ep_m014     6202
# new_ep_m1524    6214
# new_ep_m2534    6220
# new_ep_m3544    6216
# new_ep_m4554    6220
# new_ep_m5564    6225
# new_ep_m65      6222
# new_ep_f014     6208
# new_ep_f1524    6219
# new_ep_f2534    6219
# new_ep_f3544    6219
# ...

# %%
who[who.iso2.isna()]
# Out:
#       country iso2 iso3  year  new_sp_m014  new_sp_m1524  new_sp_m2534  \
# 4369  Namibia  NaN  NAM  1980          NaN           NaN           NaN
# 4370  Namibia  NaN  NAM  1981          NaN           NaN           NaN
# 4371  Namibia  NaN  NAM  1982          NaN           NaN           NaN
# 4372  Namibia  NaN  NAM  1983          NaN           NaN           NaN
# 4373  Namibia  NaN  NAM  1984          NaN           NaN           NaN
# 4374  Namibia  NaN  NAM  1985          NaN           NaN           NaN
# 4375  Namibia  NaN  NAM  1986          NaN           NaN           NaN
# 4376  Namibia  NaN  NAM  1987          NaN           NaN           NaN
# 4377  Namibia  NaN  NAM  1988          NaN           NaN           NaN
# 4378  Namibia  NaN  NAM  1989          NaN           NaN           NaN
# 4379  Namibia  NaN  NAM  1990          NaN           NaN           NaN
# 4380  Namibia  NaN  NAM  1991          NaN           NaN           NaN
# ...

# %%
# Los valores NA se debe a que el iso2 de Namibia es "NA", y pandas lo tomo como un valor faltante
who.loc[who.country == "Namibia", "iso2"] = "NA"

# %%
who.fillna(0, inplace=True)

# %%
#Checar valor faltantes en pop
pop.isna().sum()
# Out:
# country       0
# year          0
# population    0
# dtype: int64

# %%
#comoconvertir columnas en fila :: melt()
who2 = who.melt(id_vars=["country","iso2", "iso3", "year"])
who2.head(20)
# Out:
#         country iso2 iso3  year     variable  value
# 0   Afghanistan   AF  AFG  1980  new_sp_m014    0.0
# 1   Afghanistan   AF  AFG  1981  new_sp_m014    0.0
# 2   Afghanistan   AF  AFG  1982  new_sp_m014    0.0
# 3   Afghanistan   AF  AFG  1983  new_sp_m014    0.0
# 4   Afghanistan   AF  AFG  1984  new_sp_m014    0.0
# 5   Afghanistan   AF  AFG  1985  new_sp_m014    0.0
# 6   Afghanistan   AF  AFG  1986  new_sp_m014    0.0
# 7   Afghanistan   AF  AFG  1987  new_sp_m014    0.0
# 8   Afghanistan   AF  AFG  1988  new_sp_m014    0.0
# 9   Afghanistan   AF  AFG  1989  new_sp_m014    0.0
# 10  Afghanistan   AF  AFG  1990  new_sp_m014    0.0
# 11  Afghanistan   AF  AFG  1991  new_sp_m014    0.0
# 12  Afghanistan   AF  AFG  1992  new_sp_m014    0.0
# 13  Afghanistan   AF  AFG  1993  new_sp_m014    0.0
# 14  Afghanistan   AF  AFG  1994  new_sp_m014    0.0
# 15  Afghanistan   AF  AFG  1995  new_sp_m014    0.0
# 16  Afghanistan   AF  AFG  1996  new_sp_m014    0.0
# ...

# %%
#funcion para asignar el genero
def asignar_genero(valor):
  if 'm' in valor:
    return 'masculino'
  else:
    return 'femenino'

#def asignar_genero(valor):
#  if 'm' in valor:
#    return 'masculino'
#  else:
#    return 'femenino'

# %%
who2["genero"] = who2["variable"].apply(asignar_genero)
who2.head(500)
# Out:
#                  country iso2 iso3  year     variable  value     genero
# 0            Afghanistan   AF  AFG  1980  new_sp_m014    0.0  masculino
# 1            Afghanistan   AF  AFG  1981  new_sp_m014    0.0  masculino
# 2            Afghanistan   AF  AFG  1982  new_sp_m014    0.0  masculino
# 3            Afghanistan   AF  AFG  1983  new_sp_m014    0.0  masculino
# 4            Afghanistan   AF  AFG  1984  new_sp_m014    0.0  masculino
# 5            Afghanistan   AF  AFG  1985  new_sp_m014    0.0  masculino
# 6            Afghanistan   AF  AFG  1986  new_sp_m014    0.0  masculino
# 7            Afghanistan   AF  AFG  1987  new_sp_m014    0.0  masculino
# 8            Afghanistan   AF  AFG  1988  new_sp_m014    0.0  masculino
# 9            Afghanistan   AF  AFG  1989  new_sp_m014    0.0  masculino
# 10           Afghanistan   AF  AFG  1990  new_sp_m014    0.0  masculino
# 11           Afghanistan   AF  AFG  1991  new_sp_m014    0.0  masculino
# ...

# %%
#funcion para asignar el metodo
def asignar_metodo(valor):
  if 'sp' in valor:
    return 'smear positive'
  elif 'sn' in valor:
    return 'smear negative'
  elif 'ep' in valor:
    return 'extrapulmonary'
  else:
    return 'relapse'

# %%
who2["metodo"] = who2["variable"].apply(asignar_metodo)
who2.head(500)
# Out:
#                  country iso2 iso3  year     variable  value     genero  \
# 0            Afghanistan   AF  AFG  1980  new_sp_m014    0.0  masculino
# 1            Afghanistan   AF  AFG  1981  new_sp_m014    0.0  masculino
# 2            Afghanistan   AF  AFG  1982  new_sp_m014    0.0  masculino
# 3            Afghanistan   AF  AFG  1983  new_sp_m014    0.0  masculino
# 4            Afghanistan   AF  AFG  1984  new_sp_m014    0.0  masculino
# 5            Afghanistan   AF  AFG  1985  new_sp_m014    0.0  masculino
# 6            Afghanistan   AF  AFG  1986  new_sp_m014    0.0  masculino
# 7            Afghanistan   AF  AFG  1987  new_sp_m014    0.0  masculino
# 8            Afghanistan   AF  AFG  1988  new_sp_m014    0.0  masculino
# 9            Afghanistan   AF  AFG  1989  new_sp_m014    0.0  masculino
# 10           Afghanistan   AF  AFG  1990  new_sp_m014    0.0  masculino
# 11           Afghanistan   AF  AFG  1991  new_sp_m014    0.0  masculino
# ...

# %%
#funcion para asignar la edad
def asignar_grupoedad(valor):
  if '014' in valor:
    return '0-14'
  elif '1524' in valor:
    return '15-24'
  elif '2534' in valor:
    return '25-34'
  elif '3544' in valor:
    return '35-44'
  elif '4554' in valor:
    return '45-54'
  elif '5564' in valor:
    return '55-64'
  else:
    return '65+'

# %%
who2["grupoedad"] = who2["variable"].apply(asignar_grupoedad)
who2.head(10)
# Out:
#        country iso2 iso3  year     variable  value     genero          metodo  \
# 0  Afghanistan   AF  AFG  1980  new_sp_m014    0.0  masculino  smear positive
# 1  Afghanistan   AF  AFG  1981  new_sp_m014    0.0  masculino  smear positive
# 2  Afghanistan   AF  AFG  1982  new_sp_m014    0.0  masculino  smear positive
# 3  Afghanistan   AF  AFG  1983  new_sp_m014    0.0  masculino  smear positive
# 4  Afghanistan   AF  AFG  1984  new_sp_m014    0.0  masculino  smear positive
# 5  Afghanistan   AF  AFG  1985  new_sp_m014    0.0  masculino  smear positive
# 6  Afghanistan   AF  AFG  1986  new_sp_m014    0.0  masculino  smear positive
# 7  Afghanistan   AF  AFG  1987  new_sp_m014    0.0  masculino  smear positive
# 8  Afghanistan   AF  AFG  1988  new_sp_m014    0.0  masculino  smear positive
# 9  Afghanistan   AF  AFG  1989  new_sp_m014    0.0  masculino  smear positive
#
#   grupoedad
# 0      0-14
# 1      0-14
# 2      0-14
# 3      0-14
# 4      0-14
# 5      0-14
# 6      0-14
# ...

# %%
who2.drop(columns=["variable"], inplace=True)

# %%
#renombrar a value por cases
who2.rename(columns={"value":"cases"},inplace=True)

# %%
who2.head()
# Out:
#        country iso2 iso3  year  cases     genero          metodo grupoedad
# 0  Afghanistan   AF  AFG  1980    0.0  masculino  smear positive      0-14
# 1  Afghanistan   AF  AFG  1981    0.0  masculino  smear positive      0-14
# 2  Afghanistan   AF  AFG  1982    0.0  masculino  smear positive      0-14
# 3  Afghanistan   AF  AFG  1983    0.0  masculino  smear positive      0-14
# 4  Afghanistan   AF  AFG  1984    0.0  masculino  smear positive      0-14

# %%
#traer poblacion
df = pd.merge(who2, pop, on=["country", "year"], how="inner")
df.head(10)
# Out:
#        country iso2 iso3  year  cases     genero          metodo grupoedad  \
# 0  Afghanistan   AF  AFG  1995    0.0  masculino  smear positive      0-14
# 1  Afghanistan   AF  AFG  1996    0.0  masculino  smear positive      0-14
# 2  Afghanistan   AF  AFG  1997    0.0  masculino  smear positive      0-14
# 3  Afghanistan   AF  AFG  1998   30.0  masculino  smear positive      0-14
# 4  Afghanistan   AF  AFG  1999    8.0  masculino  smear positive      0-14
# 5  Afghanistan   AF  AFG  2000   52.0  masculino  smear positive      0-14
# 6  Afghanistan   AF  AFG  2001  129.0  masculino  smear positive      0-14
# 7  Afghanistan   AF  AFG  2002   90.0  masculino  smear positive      0-14
# 8  Afghanistan   AF  AFG  2003  127.0  masculino  smear positive      0-14
# 9  Afghanistan   AF  AFG  2004  139.0  masculino  smear positive      0-14
#
#    population
# 0    17586073
# 1    18415307
# 2    19021226
# 3    19496836
# 4    19987071
# 5    20595360
# 6    21347782
# 7    22202806
# ...

# %%
#guardar la tabla final en csv
df.to_csv("tuberculosis.csv")

# %%
# Analisis Exploratorio con Python
# recordemos que df es el dataframe con los datos limpios
df.head(25)
# Agrupar y resumir datos en Python
# Por genero
por_genero = df.groupby("genero", as_index=False)["cases"].sum()
por_genero["porcentaje"] = 100 * por_genero["cases"] / por_genero["cases"].sum()
por_genero.head()
# Out:
#       genero       cases  porcentaje
# 0   femenino  15818663.0   36.640815
# 1  masculino  27353584.0   63.359185

# %%
# Por metodo
por_metodo = df.groupby("metodo", as_index=False)["cases"].sum()
por_metodo["porcentaje"] = 100 * por_metodo["cases"] / por_metodo["cases"].sum()
por_metodo.head()
# Out:
#            metodo       cases  porcentaje
# 0  extrapulmonary   1986179.0    4.600592
# 1         relapse   3205329.0    7.424513
# 2  smear negative   6279526.0   14.545284
# 3  smear positive  31701213.0   73.429611

# %%
# Por edad
por_edad = df.groupby("grupoedad", as_index=False)["cases"].sum()
por_edad["porcentaje"] = 100 * por_edad["cases"] / por_edad["cases"].sum()
por_edad.head()
# Out:
#   grupoedad      cases  porcentaje
# 0      0-14  1702349.0    3.943156
# 1     15-24  7594407.0   17.590947
# 2     25-34  9562886.0   22.150540
# 3     35-44  8720495.0   20.199308
# 4     45-54  6475709.0   14.999703

# %%
# Cantidad de Paises Involucrados, Año de inicio y Año de finalizacion de los datos
print(f"Cantidad de Paises: {df.country.nunique()}")
print(f"Año de inicio: {df.year.min()}")
print(f"Año de finalizacion: {df.year.max()}")
# Out:
# Cantidad de Paises: 217
# Año de inicio: 1995
# Año de finalizacion: 2013

# %% [markdown]
# Tasa de incidencia (por cada 100 mil habitantes) =
# 100,000 * casos nuevos / poblacion

# %%
# Nueva tabla para calcular la incidencia
country_year = df.groupby(["country", "year"], as_index=False).agg({"cases": "sum", "population": "max"})
country_year["tasa_incidencia"] = 100_000 * country_year["cases"] / country_year["population"]
country_year.head()
# Out:
#        country  year   cases  population  tasa_incidencia
# 0  Afghanistan  1995     0.0    17586073         0.000000
# 1  Afghanistan  1996     0.0    18415307         0.000000
# 2  Afghanistan  1997   128.0    19021226         0.672932
# 3  Afghanistan  1998  1778.0    19496836         9.119428
# 4  Afghanistan  1999   745.0    19987071         3.727410

# %%
# Nueva tabla para calcular la incidencia POR AÑO
by_year = country_year.groupby("year", as_index=False).agg(
    {"cases": "sum", "population": "sum"}
    )
by_year["tasa_incidencia"] = 100_000 * by_year["cases"] / by_year["population"]
by_year
# Out:
#     year      cases  population  tasa_incidencia
# 0   1995   505717.0  5703289735         8.867110
# 1   1996   628318.0  5781863871        10.867049
# 2   1997   724163.0  5858936095        12.359974
# 3   1998   830998.0  5934972576        14.001716
# 4   1999   986176.0  6010587100        16.407316
# 5   2000  1148463.0  6086267209        18.869743
# 6   2001  1227501.0  6162187587        19.919890
# 7   2002  1512296.0  6239282896        24.238298
# 8   2003  1849403.0  6315958969        29.281428
# 9   2004  2172788.0  6393225245        33.985788
# 10  2005  2351620.0  6471174754        36.339924
# 11  2006  2983657.0  6549876653        45.552873
# 12  2007  3822603.0  6629328545        57.661994
# 13  2008  3519984.0  6709439312        52.463162
# 14  2009  3819894.0  6790058168        56.257162
# 15  2010  3972675.0  6870886787        57.818956
# 16  2011  3962734.0  6952175552        56.999913
# 17  2012  3947928.0  7033689262        56.128837
# ...

# %%
# 1995	tasa de incidencia: 8.867110
# 2010	tasa de incidencia: 57.818956
# tasa de variacion = (tasa_de_incidencia_final - tasa_de_incidencia_inicial) /tasa_de_incidencia_inicial
100 * (57.818956 - 8.867110) /  8.867110
# Out:
# 552.0608856775207

# %%
import matplotlib.pyplot as plt # base de visualizacion en Python
import seaborn as sns # visualizaciones mas sencillas hechas encima de Matplotlib
import plotly.express as px # visualizaciones interactivas

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="year", y="tasa_incidencia", data=by_year)
plt.title("Tasa de incidencia por año")
plt.xlabel("Año")
plt.ylabel("Tasa de incidencia")
plt.savefig("/content/drive/MyDrive/Colab Notebooks/grafica_incidencia.png")

# %%
# grafica de barras con plotly
fig = px.bar(by_year, x="year", y="tasa_incidencia")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
before_df = df[df.year < 2010]

# %%
before_df.head(100)

before_df.to_csv('/content/drive/MyDrive/Datos/PyAza/before_df.csv', index=False)
df.to_csv('/content/drive/MyDrive/Datos/PyAza/df.csv', index=False)
# Out:
#             country iso2 iso3  year  cases     genero          metodo  \
# 0       Afghanistan   AF  AFG  1995    0.0  masculino  smear positive
# 1       Afghanistan   AF  AFG  1996    0.0  masculino  smear positive
# 2       Afghanistan   AF  AFG  1997    0.0  masculino  smear positive
# 3       Afghanistan   AF  AFG  1998   30.0  masculino  smear positive
# 4       Afghanistan   AF  AFG  1999    8.0  masculino  smear positive
# 5       Afghanistan   AF  AFG  2000   52.0  masculino  smear positive
# 6       Afghanistan   AF  AFG  2001  129.0  masculino  smear positive
# 7       Afghanistan   AF  AFG  2002   90.0  masculino  smear positive
# 8       Afghanistan   AF  AFG  2003  127.0  masculino  smear positive
# 9       Afghanistan   AF  AFG  2004  139.0  masculino  smear positive
# 10      Afghanistan   AF  AFG  2005  151.0  masculino  smear positive
# 11      Afghanistan   AF  AFG  2006  193.0  masculino  smear positive
# ...
